# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np

# %%
im1=cv2.imread("14.jpeg")

# %%
plt.imshow(im1)
plt.title('img')
plt.show()

# %% [markdown]
# ##
